# %% [markdown]
# # Earthquake damage classification

# %% [markdown]
# ## 19 September 2017, Mw7.1 Puebla Earthquake, Mexico 🇲🇽

# %% [markdown]
# ## 0: Preliminaries

# %% [markdown]
# ### Import python libraries

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import fiona
import folium
import rasterio
import rasterio.mask
import rasterstats as rs
import seaborn as sns
from shapely.geometry import Point
from time import time
import matplotlib.pyplot as plt
# %matplotlib inline
starttime = time()
# Out:
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# ### Set the default coordinate reference system

# %%
dst_crs = "EPSG:4326"

# %% [markdown]
# ### Indicate paths to input files

# %%
event_name = "M7.1 Puebla Earthquake, Mexico"
dpm_raw_file = "DPM/DPM2_S1_MexicoCity_20170920_raw.tif"
dpm_clipped_file = "DPM/DPM2_S1_MexicoCity_20170920_ShakeMapMask.tif"
# building_footprints_file = "Buildings/Buildings.geojson"
damage_labels_file = "DamageLabels/Danos.gpkg"
shakemap_url = "https://earthquake.usgs.gov/product/shakemap/us2000ar20/atlas/1594399976203/download/"
shakemap_json = shakemap_url + "cont_mmi.json" # Contours
shakemap_zip = shakemap_url + "shape.zip" # Polygons

# %% [markdown]
# ## 1: Demarcate affected area

# %% [markdown]
# ### Draw an empty map centered on the event¶

# %%
lat = +18.550
lon = -98.489

bound_n = lat + 3
bound_e = lon + 3
bound_s = lat - 3
bound_w = lon - 3

m = folium.Map(
    location=[lat, lon], 
    zoom_start=7,
    tiles='Stamen Terrain')

folium.CircleMarker(
    location=[lat, lon],
    radius=5,
    tooltip="Epicenter",
    popup=event_name,
    color="IndianRed",
    fill_color="LightCoral",
    fill=True
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1369f98c36d34b6ab9f588fc2354c0e1%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1369f98c36d34b6ab9f588fc2354c0e1%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1369f98c36d34b6ab9f588fc2354c0e1%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1369f98c36d34b6ab9f588fc2354c0e1%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B18.55%2C%20-98.489%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### Draw ShakeMap contours for MMI ≥ V

# %%
style_function = lambda x: {
    'color': x["properties"]["color"],
    'weight': x["properties"]["weight"] if x["properties"]["value"] >= 5 else 0
}
tooltip = folium.features.GeoJsonTooltip(fields=["value"])

folium.GeoJson(
    shakemap_json,
    name="ShakeMap Contours",
    style_function=style_function,
    tooltip=tooltip
).add_to(m)

folium.TileLayer('OpenStreetMap').add_to(m)
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1369f98c36d34b6ab9f588fc2354c0e1%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20table%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20margin%3A%20auto%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### Save the MMI V contour as a vector layer

# %%
shakemap_gdf = gpd.read_file(shakemap_json)
shakemapV_gdf = shakemap_gdf[shakemap_gdf.value==5]
shakemapV_gdf.to_file("ShakeMap/MMI_V_Contours.gpkg", driver="GPKG")
shakemapV_gdf.convex_hull.to_file("ShakeMap/MMI_V_Envelope.gpkg", driver="GPKG")

# %% [markdown]
# ## 2: Load DPM tiles and mask to built areas within MMI≥V

# %% [markdown]
# ### Read the DPM raster and mask it using the MMI V contour

# %%
from rasterio.warp import calculate_default_transform, reproject, Resampling

with fiona.open("ShakeMap/MMI_V_Envelope.gpkg", "r") as shapefile:
    shapes = [feature["geometry"] for feature in shapefile]

with rasterio.open(dpm_raw_file) as src:
    out_image, out_transform = rasterio.mask.mask(src, shapes, crop=True)
    out_meta = src.meta
    
out_meta.update({"driver": "GTiff",
                 "height": out_image.shape[1],
                 "width": out_image.shape[2],
                 "transform": out_transform})

with rasterio.open(dpm_clipped_file, "w", **out_meta) as dest:
    dest.write(out_image)

# %% [markdown]
# ### Explore the distribution of the clipped DPM pixel values by plotting a histogram

# %%
from rasterio.plot import show_hist
dpm_src = rasterio.open(dpm_raw_file)
show_hist(
    dpm_src, bins=64, lw=0.0, stacked=False, alpha=0.3,
    histtype='stepfilled', title="Distribution of DPM Raw Pixel Values")

# %% [markdown]
# ## 3: Load and plot the building inventory files

# %% [markdown]
# ### Load the building inventory file for Budhanilkantha

# %%
# bldgs_gdf = gpd.read_file(building_footprints_file)

# %% [markdown]
# ### Inspect the building inventory file

# %%
# bldgs_gdf.head()

# %% [markdown]
# ### Drop unnecessary columns

# %%
# bldgs_gdf.drop(columns=["fid", "ObjectType", "PROMJENA"], inplace=True)

# %% [markdown]
# ## 4: Join the damage labels to the building inventory

# %% [markdown]
# ### Load the damage labels ("ground truth" / "test labels")

# %%
dmg_labels_gdf = gpd.read_file(damage_labels_file)
dmg_labels_gdf.set_index("Immuebla", inplace=True)

# Limit dataset to CDMX as building attributes are 
# not available for Puebla and Mexico states
dmg_labels_gdf = dmg_labels_gdf.loc[dmg_labels_gdf.Zona == "17M"]

# %% [markdown]
# ### Inspect the damage labels layer contents

# %%
dmg_labels_gdf.head()
# Out:
#             Zona  Edificio                        Uso  \
# Immuebla
# 17M|COY_127  17M  Edificio  Edificio de departamentos
# 17M|COY_69   17M      Casa  Edificio de departamentos
# 17M|COY_05   17M  Edificio  Edificio de departamentos
# 17M|COY_128  17M     Plaza                   Comercio
# 17M|COY_93   17M  Edificio  Edificio de departamentos
#
#                                    Calle  \
# Immuebla
# 17M|COY_127           Av. Cafetales 1819
# 17M|COY_69   Cda. Francisco I. Madero 86
# 17M|COY_05        Rancho de los Arcos 32
# 17M|COY_128          Calz. Del Hueso 480
# 17M|COY_93      Canal de Miramontes 3040
#
#                                                Calle2  \
# Immuebla
# 17M|COY_127        Calz. Taxqueña y Cerro San Antonio
# 17M|COY_69             Ignacio Zaragoza y Bugambilias
# 17M|COY_05      Calz del Hueso y Rancho Vista Hermosa
# 17M|COY_128  Rancho Vista Hermosa y Calzada del Hueso
# 17M|COY_93            E. Pallares & Potillo y América
#
#                                        Colonia Delegación/Colonia  \
# Immuebla
# 17M|COY_127               Campestre Churubusco           Coyoacán
# 17M|COY_69   Viejo Ejido de Santa Úrsula Coapa           Coyoacán
# 17M|COY_05                           Girasoles           Coyoacán
# 17M|COY_128                       Girasoles II           Coyoacán
# 17M|COY_93                    Barrio San Lucas           Coyoacán
#
#              Año estimado de construcción  Número de pisos:  \
# Immuebla
# 17M|COY_127                        1964.0                 5
# 17M|COY_69                         1991.0                 4
# 17M|COY_05                         1984.0                 6
# 17M|COY_128                        1980.0                 2
# 17M|COY_93                         1976.0                 7
#
#                                      Sistema estructural  ...  \
# Immuebla                                                  ...
# 17M|COY_127  Marcos de concreto con muros de mampostería  ...
# 17M|COY_69                Muros de mampostería confinada  ...
# 17M|COY_05             Columnas y losa plana de concreto  ...
# 17M|COY_128                           Marcos de concreto  ...
# 17M|COY_93   Marcos de concreto con muros de mampostería  ...
#
#              Periodo estimado del suelo (Ts)  amax Estructura  amax Suelo  \
# Immuebla
# 17M|COY_127                         1.679248         88.67672    238.0075
# 17M|COY_69                          0.689696        145.38220    232.7418
# 17M|COY_05                          1.166782        141.59800    617.8574
# 17M|COY_128                         1.127257        141.59800    318.7860
# 17M|COY_93                          1.126042        141.59800    530.1363
#
#              Cociente Te/Ts             Daño  \
# Immuebla
# 17M|COY_127        0.285842          Menores
# 17M|COY_69         0.458173          Menores
# 17M|COY_05         0.649019    Colapso total
# 17M|COY_128        0.249928  Colapso parcial
# 17M|COY_93         0.548634           Graves
#
#                                            Daño en Estructuras  \
# Immuebla
# 17M|COY_127   Grietas en acabados y elementos no estructurales
# 17M|COY_69    Grietas en acabados y elementos no estructurales
# 17M|COY_05   Colapso de la planta baja o de toda la estructura
# 17M|COY_128                        Colapso de pisos superiores
# 17M|COY_93         Grietas grandes en muros, trabes o columnas
#
#                                                  Observaciones  \
# Immuebla
# 17M|COY_127  Agrietamiento por cortante de un muro de la pl...
# 17M|COY_69                            Pequeñas Grietas en viga
# 17M|COY_05                     Colapso total de la estructura.
# 17M|COY_128  Colapso de una esquina del local, daños en otr...
# 17M|COY_93   Agrietamiento por cortante en muros de mampost...
#
#                                        Agravante de los daños    MM  \
# Immuebla
# 17M|COY_127                           Irregularidad en planta  4970
# 17M|COY_69                                 Ninguno apreciable  4980
# 17M|COY_05                            Irregularidad en planta  4920
# 17M|COY_128        Efecto de esquina\nIrregularidad en planta  4920
# 17M|COY_93   Irregularidad en planta\nEfecto de columna corta  4920
#
#                                                       geometry
# Immuebla
# 17M|COY_127  POLYGON ((-99.11361 19.30128, -99.11364 19.301...
# 17M|COY_69   POLYGON ((-99.14357 19.30151, -99.14363 19.301...
# 17M|COY_05   POLYGON ((-99.12294 19.30465, -99.12294 19.304...
# 17M|COY_128  POLYGON ((-99.12367 19.30424, -99.12371 19.303...
# 17M|COY_93   POLYGON ((-99.12400 19.30472, -99.12402 19.304...
#
# [5 rows x 21 columns]

# %%
dmg_labels_gdf = dmg_labels_gdf[["Año estimado de construcción", "Número de pisos:", "Sistema estructural", "Periodo estimado del suelo (Ts)", "Daño", "geometry"]]

# %%
# Clean up field names
dmg_labels_gdf.rename(
    columns={
    "Año estimado de construcción": "CONSTR_YEAR", 
    "Número de pisos:": "NUM_FLOORS", 
    "Periodo estimado del suelo (Ts)": "SOIL_PERIOD", 
    "Sistema estructural": "CONSTR_TYPE", 
    "Daño": "DAMAGE_GRADE",
    }, 
    inplace=True)

# Inspect contents of the revised files
dmg_labels_gdf.head()
# Out:
#              CONSTR_YEAR  NUM_FLOORS  \
# Immuebla
# 17M|COY_127       1964.0           5
# 17M|COY_69        1991.0           4
# 17M|COY_05        1984.0           6
# 17M|COY_128       1980.0           2
# 17M|COY_93        1976.0           7
#
#                                              CONSTR_TYPE  SOIL_PERIOD  \
# Immuebla
# 17M|COY_127  Marcos de concreto con muros de mampostería     1.679248
# 17M|COY_69                Muros de mampostería confinada     0.689696
# 17M|COY_05             Columnas y losa plana de concreto     1.166782
# 17M|COY_128                           Marcos de concreto     1.127257
# 17M|COY_93   Marcos de concreto con muros de mampostería     1.126042
#
#                 DAMAGE_GRADE  \
# Immuebla
# 17M|COY_127          Menores
# 17M|COY_69           Menores
# 17M|COY_05     Colapso total
# 17M|COY_128  Colapso parcial
# 17M|COY_93            Graves
#
#                                                       geometry
# Immuebla
# 17M|COY_127  POLYGON ((-99.11361 19.30128, -99.11364 19.301...
# 17M|COY_69   POLYGON ((-99.14357 19.30151, -99.14363 19.301...
# 17M|COY_05   POLYGON ((-99.12294 19.30465, -99.12294 19.304...
# 17M|COY_128  POLYGON ((-99.12367 19.30424, -99.12371 19.303...
# 17M|COY_93   POLYGON ((-99.12400 19.30472, -99.12402 19.304...

# %%
# Inspect the damage grade labels column
ax = (dmg_labels_gdf.DAMAGE_GRADE
      .value_counts()
      .sort_index()
      .plot.bar(
          title="Damage Labels"
      ))
for p in ax.patches:
    ax.annotate(
        p.get_height(), (p.get_x()+p.get_width()/2., p.get_height()), 
        ha='center', va='center', 
        xytext=(0, 10), textcoords='offset points')

# %% [markdown]
# ### Explanation of damage labels
# The damage labels are based on the EMS-98 scale.
# Data source: National Society of Earthquake Technology - Nepal (NSET) and Budhanilkantha Municipality, Kathmandu District
#
# ![EMS-98 Damage Grades](https://emergency.copernicus.eu/mapping/sites/default/files/images/DamageAssessement_classification.png)

# %% [markdown]
# ### Relabel the damage grade labels column with English names

# %%
dmg_labels_gdf.replace(
    to_replace={
        "DAMAGE_GRADE":{
            "Menores": "1",
            "Intermedio": "2",
            "Graves": "3",
            "Colapso parcial": "4", 
            "Colapso total": "5"}},
    inplace=True)

# Group similar construction types to reduce the number of classes
dmg_labels_gdf.replace(
    to_replace={
        "CONSTR_TYPE":{
            "Marcos de concreto con muros de mampostería": "Reinforced concrete",
            "Muros de mampostería confinada": "Confined masonry",
            "Columnas y losa plana de concreto": "Reinforced concrete",
            "Marcos de concreto": "Reinforced concrete",
            "Marcos de acero": "Steel frame",
            "Mampostería histórica": "Unreinforced masonry",
            "Muros de mampostería de adobe": "Adobe",
            "Muros de mampostería no confinada": "Unreinforced masonry",
            "Marcos de columnas de concreto y trabes de acero": "Reinforced concrete",
            "Marcos de concreto con muros de concreto": "Reinforced concrete",
            "Marcos de concreto y contravientos de acero": "Reinforced concrete",
            "Estructura metálica": "Other",
            "Marcos y muros de concreto": "Reinforced concrete",
            "Pavimento asfáltico": "Other",
            "Columnas y trabes presforzadas de concreto": "Reinforced concrete",
            "Concreto reforzado": "Reinforced concrete",
            "Columnas y losas planas de concreto": "Reinforced concrete",
            "Mixta": "Other",
            "NA": "Other",}},
    inplace=True)

# Inspect the damage grades database
dmg_labels_gdf.head()
# Out:
#              CONSTR_YEAR  NUM_FLOORS          CONSTR_TYPE  SOIL_PERIOD  \
# Immuebla
# 17M|COY_127       1964.0           5  Reinforced concrete     1.679248
# 17M|COY_69        1991.0           4     Confined masonry     0.689696
# 17M|COY_05        1984.0           6  Reinforced concrete     1.166782
# 17M|COY_128       1980.0           2  Reinforced concrete     1.127257
# 17M|COY_93        1976.0           7  Reinforced concrete     1.126042
#
#             DAMAGE_GRADE                                           geometry
# Immuebla
# 17M|COY_127            1  POLYGON ((-99.11361 19.30128, -99.11364 19.301...
# 17M|COY_69             1  POLYGON ((-99.14357 19.30151, -99.14363 19.301...
# 17M|COY_05             5  POLYGON ((-99.12294 19.30465, -99.12294 19.304...
# 17M|COY_128            4  POLYGON ((-99.12367 19.30424, -99.12371 19.303...
# 17M|COY_93             3  POLYGON ((-99.12400 19.30472, -99.12402 19.304...

# %%
ax = (dmg_labels_gdf.DAMAGE_GRADE
      .value_counts()
      .sort_index()
      .plot.bar(
          title="Damage Labels",
          color=["Yellow", "Gold", "Orange", "Coral", "IndianRed"],
      ))
for p in ax.patches:
    ax.annotate(
        p.get_height(), (p.get_x()+p.get_width()/2., p.get_height()), 
        ha='center', va='center', 
        xytext=(0, 10), textcoords='offset points')

# %% [markdown]
# #### Note: This is an imbalanced dataset
# The number of samples in Damage Grade "1" is roughly one order of magnitude larger than the number of samples in Damage Grades "4" and "5". Most machine learning multiclass classification algorithms assume that all classes have roughly similar numbers of examples.
#
# To circumvent this issue, one potential route is to modify the training set to have similar numbers of examples in each category, for instance by oversampling training examples from the classes with fewer examples.
#
# Another route is to modify the classification algorithm by changing the way learning is performed, preferably biasing more towards those classes that have fewer examples in the training dataset. This is generally called cost-sensitive learning.

# %%
# Inspect the coordinate reference system used by the damage database
dmg_labels_gdf.crs

# %%
# Reproject the damage dataset to the project coordinate reference system
dmg_labels_gdf = dmg_labels_gdf.to_crs(dst_crs)

# %% [markdown]
# ### Join the damage labels to the building inventory

# %%
# Building footprints available from OSM for CDMX do not
# have information about number of stories and year
# of construction that is available in the damage dataset
# We focus this example only on damaged buildings
input_gdf = dmg_labels_gdf

# %% [markdown]
# ## 5. Join ShakeMap intensity to building inventory

# %% [markdown]
# ### Join ShakeMap value to the building inventory

# %%
# Build url for the ShakeMap polygons shapefile and perform a spatial join
tic = time()
shakemap_shp = f"zip+{shakemap_zip}!mi.shp"
shakemap_gdf = gpd.read_file(shakemap_shp)
inputs_gdf = gpd.sjoin(input_gdf, shakemap_gdf, how="left", op="within")
print(f"Spatial join completed in {time() - tic:.0f}s")
# Out:
# Spatial join completed in 5s

# %%
# Drop unneeded columns and rename the remaining ones
inputs_gdf.drop(columns=["index_right", "AREA", "PERIMETER", "PGAPOL_", "PGAPOL_ID", "GRID_CODE"], inplace=True)
inputs_gdf.rename(columns={"Area": "AREA", "layer": "BLDG_TYPE", "PARAMVALUE": "MMI"}, inplace=True)

# %%
# Create both string and numeric versions of the shaking intensity vector
inputs_strings = inputs_gdf.astype({"MMI": str, "DAMAGE_GRADE":str})
inputs_numeric = inputs_gdf.astype({"MMI": float, "DAMAGE_GRADE":int})

# %%
# Inspect the joined dataset
inputs_numeric.head()
# Out:
#              CONSTR_YEAR  NUM_FLOORS          CONSTR_TYPE  SOIL_PERIOD  \
# Immuebla
# 17M|COY_127       1964.0           5  Reinforced concrete     1.679248
# 17M|COY_69        1991.0           4     Confined masonry     0.689696
# 17M|COY_05        1984.0           6  Reinforced concrete     1.166782
# 17M|COY_128       1980.0           2  Reinforced concrete     1.127257
# 17M|COY_93        1976.0           7  Reinforced concrete     1.126042
#
#              DAMAGE_GRADE                                           geometry  \
# Immuebla
# 17M|COY_127             1  POLYGON ((-99.11361 19.30128, -99.11364 19.301...
# 17M|COY_69              1  POLYGON ((-99.14357 19.30151, -99.14363 19.301...
# 17M|COY_05              5  POLYGON ((-99.12294 19.30465, -99.12294 19.304...
# 17M|COY_128             4  POLYGON ((-99.12367 19.30424, -99.12371 19.303...
# 17M|COY_93              3  POLYGON ((-99.12400 19.30472, -99.12402 19.304...
#
#              MMI
# Immuebla
# 17M|COY_127  7.2
# 17M|COY_69   6.8
# 17M|COY_05   7.0
# 17M|COY_128  7.0
# 17M|COY_93   7.0

# %%
sns.set_theme(style="ticks")
sns.jointplot(
    data=inputs_numeric, 
    x="MMI", y="DAMAGE_GRADE", 
    marker="+", s=100, 
    marginal_kws=dict(bins=25, fill=False),
)
# Out:
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)

# %% [markdown]
# ## 6: Join DPM values to the input dataset

# %% [markdown]
# ### Find the maximum DPM value falling within each buffered building polygon

# %%
# This step can take several minutes, depending on the sizes
# of the building inventory + damage database and the DPM raster
tic = time()
with rasterio.open(dpm_clipped_file) as dpm_src:
    dpm_data = dpm_src.read(1, masked=True)
    dpm_meta = dpm_src.profile
    
inputs_list = rs.zonal_stats(
    inputs_numeric,
    dpm_data,
    nodata=-999,
    affine=dpm_meta['transform'],
    geojson_out=True,
    copy_properties=True,
    stats="max")

print(f"Zonal stats query completed in {time() - tic:.0f}s")

# View object type
type(inputs_list)
# Out:
# Zonal stats query completed in 5s
# list

# %% [markdown]
# ### Create dataframe with input variable values and labels

# %%
inputs_gdf = gpd.GeoDataFrame.from_features(inputs_list)
inputs_gdf.rename(columns={"max": "DPM_MAX"}, inplace=True)

inputs_gdf.head()
# Out:
#                                             geometry          CONSTR_TYPE  \
# 0  POLYGON ((-99.11361 19.30128, -99.11364 19.301...  Reinforced concrete
# 1  POLYGON ((-99.14357 19.30151, -99.14363 19.301...     Confined masonry
# 2  POLYGON ((-99.12294 19.30465, -99.12294 19.304...  Reinforced concrete
# 3  POLYGON ((-99.12367 19.30424, -99.12371 19.303...  Reinforced concrete
# 4  POLYGON ((-99.12400 19.30472, -99.12402 19.304...  Reinforced concrete
#
#    CONSTR_YEAR  DAMAGE_GRADE  MMI  NUM_FLOORS  SOIL_PERIOD   DPM_MAX
# 0       1964.0             1  7.2           5     1.679248  0.650247
# 1       1991.0             1  6.8           4     0.689696       NaN
# 2       1984.0             5  7.0           6     1.166782  0.552528
# 3       1980.0             4  7.0           2     1.127257  0.747877
# 4       1976.0             3  7.0           7     1.126042  0.785846

# %%
# Plot a histogram of the joined DPM values
# This ignores NaN values, i.e., those buildings for which no DPM value was assigned
dpm_hist = inputs_gdf.DPM_MAX.hist(bins=20)
len(inputs_gdf)
# Out:
# 1277

# %%
# Drop buildings with no DPM value, as the DPM does
# not cover the entirety of the damage dataset
inputs_gdf.dropna(subset=["DPM_MAX"], inplace=True)
dpm_hist = inputs_gdf.DPM_MAX.hist(bins=20)
len(inputs_gdf)
# Out:
# 727

# %% [markdown]
# ## 7: Extract and explore the training features and training labels

# %% [markdown]
# ### Extract the training labels and values as vectors

# %%
inputs_gdf["CONSTR_YEAR"] = inputs_gdf.CONSTR_YEAR.replace({0: 1980}) # Modal construction year
inputs_gdf["AGE"] = 2017 - inputs_gdf.CONSTR_YEAR
inputs_gdf["AGE"] = inputs_gdf.AGE.clip(upper=90) # Clip age at 90 to avoid extreme outliers

# %%
# Plot histogram of the ages of the buildings
inputs_gdf.AGE.hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
# Plot histogram of the number of floors
inputs_gdf.NUM_FLOORS.hist(bins=25, range=(1, 25))
# Out:
# <AxesSubplot:>

# %%
# Convert the only categorical field, ie, the construction type
# into a numerical field, where the order matters – we apply
# an opinionated ranking of the construction types 
# from most vulnerable (class 1 = Adobe), 
# to least vulnerable (class 6 = Steel frame)
inputs_gdf.replace(
    to_replace={
        "CONSTR_TYPE":{
            "Adobe": 1,
            "Unreinforced masonry": 2,
            "Other": 3,
            "Confined masonry": 4,
            "Reinforced concrete": 5,
            "Steel frame": 6,}},
    inplace=True)

# %%
# Plot histogram of the construction type
inputs_gdf.CONSTR_TYPE.hist(bins=6)
# Out:
# <AxesSubplot:>

# %%
inputs_gdf.dropna(inplace=True)

# %% [markdown]
# ## 7: Extract and explore the training features and training labels

# %% [markdown]
# ### Extract the training labels and values as vectors

# %%
train_values = inputs_gdf[["CONSTR_TYPE", "AGE", "NUM_FLOORS", "SOIL_PERIOD", "MMI", "DPM_MAX"]]
train_labels = inputs_gdf[["DAMAGE_GRADE"]]

# %%
train_values.dtypes
# Out:
# CONSTR_TYPE      int64
# AGE            float64
# NUM_FLOORS       int64
# SOIL_PERIOD    float64
# MMI            float64
# DPM_MAX        float64
# dtype: object

# %%
train_labels.dtypes
# Out:
# DAMAGE_GRADE    int64
# dtype: object

# %% [markdown]
# ### Explore the training data

# %%
ax = (train_labels.DAMAGE_GRADE
      .value_counts()
      .sort_index()
      .plot.bar(
          title="Number of Buildings in Each Damage Grade",
          color=["Yellow", "Gold", "Orange", "Coral", "IndianRed"],
      ))
for p in ax.patches:
    ax.annotate(
        p.get_height(), (p.get_x()+p.get_width()/2., p.get_height()), 
        ha='center', va='center', 
        xytext=(0, 10), textcoords='offset points')

# %% [markdown]
# ### Select subset of features to use for training

# %%
selected_features = ["CONSTR_TYPE", "AGE", "NUM_FLOORS", "SOIL_PERIOD", "MMI", "DPM_MAX"]
train_values_subset = train_values[selected_features]

# %% [markdown]
# ### Explore the relationships between the numeric features and labels

# %%
sns.set_theme(style="ticks")
train_values_subset_plot = train_values_subset.replace(0, np.nan)
sns.pairplot(
    train_values_subset_plot.join(train_labels),
    hue="DAMAGE_GRADE",
    hue_order=[5, 4, 3, 2, 1],
    palette={1:"Yellow", 2:"Gold", 3:"Orange", 4:"Coral", 5:"IndianRed"},
    markers=["1", "2", "3", "4", "+"],
    kind="scatter",
    diag_kind="hist",
    corner=True,
    plot_kws={'alpha':0.6, 'linewidth':1},
    diag_kws={'fill':True},
    grid_kws={'diag_sharey':False},
)
plt.savefig("Figures/PairPlot_DS5.png")
# Out:
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)

# %%
# Ignore Damage Grade 0 for the plots
sns.pairplot(
    train_values_subset_plot.join(train_labels).replace(0, np.nan),
    hue="DAMAGE_GRADE",
    hue_order=[5, 4, 3, 2, 1],
    palette={1:"Yellow", 2:"Gold", 3:"Orange", 4:"Coral", 5:"IndianRed"},
    markers=["2", "3", "4", "+", "x"],
    kind="scatter",
    diag_kind="hist",
    corner=True,
    plot_kws={'alpha':0.6, 'linewidth':1},
    diag_kws={'fill':True},
    grid_kws={'diag_sharey':False},
)
plt.savefig("Figures/PairPlot_DS5.png")
# Out:
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('2').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)

# %% [markdown]
# ## 8: Build the ML model(s)

# %% [markdown]
# ### Import modules for the machine learning training component

# %%
# for preprocessing the data
from sklearn.preprocessing import StandardScaler

# for splitting the data into training and test sets
from sklearn.model_selection import train_test_split

# the model(s)
from sklearn.ensemble import ExtraTreesClassifier

# for combining the preprocess with model training
from sklearn.pipeline import make_pipeline

# for optimizing the hyperparameters of the pipeline
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Split dataset into training and test subsets
#
# When performing a (supervised) machine learning experiment, it is common to hold out part of the available data as a test set `X_test, y_test`. The best parameters can be determined by grid search techniques.

# %%
X_train, X_test, y_train, y_test = train_test_split(train_values_subset, train_labels, train_size=0.70, test_size=0.30, random_state=40)

# %% [markdown]
# ### Use a Extra Trees Classifier with class weights

# %%
pipe = make_pipeline(
    StandardScaler(),
    ExtraTreesClassifier(
        random_state=42,
        max_depth=None,
        min_samples_split=2,
        max_features="sqrt",
        class_weight="balanced"
    )
)
pipe
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('extratreesclassifier',
#                  ExtraTreesClassifier(class_weight='balanced',
#                                       max_features='sqrt', random_state=42))])

# %% [markdown]
# ### Train an extra trees model with different parameters using grid search

# %% [markdown]
# A extra trees classifier is a meta estimator that fits a number of decision tree classifiers on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting.

# %%
param_grid = {'extratreesclassifier__n_estimators': [50, 100],
              'extratreesclassifier__min_samples_leaf': [1, 5]}
gs = GridSearchCV(pipe, param_grid, cv=5)

# %%
tic = time()
gs.fit(X_train, y_train.values.ravel())
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('extratreesclassifier',
#                                         ExtraTreesClassifier(class_weight='balanced',
#                                                              max_features='sqrt',
#                                                              random_state=42))]),
#              param_grid={'extratreesclassifier__min_samples_leaf': [1, 5],
#                          'extratreesclassifier__n_estimators': [50, 100]})

# %%
print(f"Model fit completed in {time() - tic:.0f}s")
# Out:
# Model fit completed in 3s

# %% [markdown]
# ### Model with the best parameters

# %%
gs.best_params_
# Out:
# {'extratreesclassifier__min_samples_leaf': 1,
#  'extratreesclassifier__n_estimators': 50}

# %% [markdown]
# ### Evaluate the model prediction performance on the _training set_

# %%
# Evaluation metrics
# from sklearn.metrics import roc_curve # restricted to the binary classification case
# from sklearn.metrics import plot_precision_recall_curve # restricted to the binary classification case
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import f1_score

# %% [markdown]
# #### Compute the F1 score, also known as balanced F-score or F-measure for the _training_ set
#
# The F1 score can be interpreted as a weighted average of the precision and recall, where an F1 score reaches its best value at 1 and worst score at 0. The relative contribution of precision and recall to the F1 score are equal. The formula for the F1 score is:
#
# `F1 = 2 * (precision * recall) / (precision + recall)`
#
# In our multi-class case, this is the average of the F1 score of each class with weighting depending on the average parameter.

# %%
# Calculate metrics globally by counting the total true positives, 
# false negatives and false positives.
in_sample_preds = gs.predict(train_values_subset)
f1_score(train_labels, in_sample_preds, average='micro')
# Out:
# 0.8787446504992867

# %%
# Calculate metrics for each label, and find their average weighted 
# the number of true instances for each label. This alters ‘macro’ to 
# account for label imbalance; it can result in an F-score that is not 
# between precision and recall.
f1_score(train_labels, in_sample_preds, average='weighted')
# Out:
# 0.87388766117473

# %%
# Calculate metrics for each label, and find their unweighted mean. 
# This does not take label imbalance into account.
f1_score(train_labels, in_sample_preds, average='macro')
# Out:
# 0.8129841912194852

# %% [markdown]
# #### Print balanced accuracy score for predictions on the _training_ set
#
# The balanced_accuracy_score function computes the balanced accuracy, which avoids inflated performance estimates on imbalanced datasets. It is the macro-average of recall scores per class or, equivalently, raw accuracy where each sample is weighted according to the inverse prevalence of its true class. For balanced datasets, the score is equal to accuracy.

# %%
balanced_accuracy_score(train_labels, in_sample_preds)
# Out:
# 0.7486307484688052

# %% [markdown]
# #### Print classification report for predictions on the _training_ set
# The precision is the ratio `tp / (tp + fp)` where `tp` is the number of true positives and `fp` the number of false positives. The precision is intuitively the ability of the classifier not to label as positive a sample that is negative.
#
# The recall is the ratio `tp / (tp + fn)` where `tp` is the number of true positives and `fn` the number of false negatives. The recall is intuitively the ability of the classifier to find all the positive samples.

# %%
target_names = ["Slight Damage", "Intermediate Damage", "Heavy Damage", "Partial Collapse", "Total Collapse"]
print(classification_report(train_labels, in_sample_preds, target_names=target_names))
# Out:
#                      precision    recall  f1-score   support
#
#       Slight Damage       0.87      0.98      0.92       435
# Intermediate Damage       0.90      0.74      0.81       169
#        Heavy Damage       0.91      0.69      0.78        58
#    Partial Collapse       0.88      0.74      0.80        19
#      Total Collapse       1.00      0.60      0.75        20
#
#            accuracy                           0.88       701
#           macro avg       0.91      0.75      0.81       701
#        weighted avg       0.88      0.88      0.87       701

# %% [markdown]
# #### Display the confusion matrix for the predictions on the _training_ set

# %%
confusion_matrix(train_labels, in_sample_preds)
# Out:
# array([[425,   8,   2,   0,   0],
#        [ 42, 125,   2,   0,   0],
#        [ 13,   3,  40,   2,   0],
#        [  3,   2,   0,  14,   0],
#        [  7,   1,   0,   0,  12]])

# %% [markdown]
# #### Plot confusion matrix with absolute, non-normalized values

# %%
plot_confusion_matrix(
    gs, train_values_subset, train_labels,
    values_format=",",
    cmap="viridis"
)

# %% [markdown]
# #### Plot confusion matrix with normalized values

# %%
plot_confusion_matrix(
    gs, train_values_subset, train_labels,
    normalize="true",
    values_format=".2f",
    cmap="cividis"
)

# %% [markdown]
# ### Partial Dependence and Individual Conditional Expectation

# %%
from sklearn.inspection import partial_dependence
from sklearn.inspection import plot_partial_dependence

# %%
tic = time()
numeric_features = ["CONSTR_TYPE", "AGE", "NUM_FLOORS", "SOIL_PERIOD", "MMI", "DPM_MAX"]
categorical_features = []
display = plot_partial_dependence(
    gs, X_train, numeric_features, target=5
)
print(f"Plot generated in {time() - tic:.0f}s")
display.figure_.suptitle(
    'Partial dependence of Damage Grade 5 on construction type,\n'
    'age of the building, number of stories, soil period,\n'
    'shaking intensity (MMI) and the DPM value'
)
display.figure_.subplots_adjust(hspace=0.5)
# Out:
# Plot generated in 4s

# %% [markdown]
# ### Feature importance based on feature permutation

# %%
from sklearn.inspection import permutation_importance

tic = time()
result = permutation_importance(
    gs, X_test, y_test, n_repeats=10, random_state=42, n_jobs=2)
print(f"Computed relative feature importances in {time() - tic:.0f}s")

importances = pd.Series(result.importances_mean, index=numeric_features)
# Out:
# Computed relative feature importances in 2s

# %%
fig, ax = plt.subplots()
importances.plot.bar(yerr=result.importances_std, ax=ax)
ax.set_title("Feature importances using permutation on full model")
ax.set_ylabel("Mean accuracy decrease")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 9: Make predictions on the test set and evaluate the model performance

# %% [markdown]
# ### Use the trained ML model to make predictions on the test set

# %%
y_pred = gs.predict(X_test)

# %% [markdown]
# ### Evaluate the model prediction performance on the _test_ set

# %% [markdown]
# #### Display the confusion matrix for the predictions on the _test_ set

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[120,   8,   2,   0,   0],
#        [ 42,   5,   2,   0,   0],
#        [ 13,   3,   1,   2,   0],
#        [  3,   2,   0,   0,   0],
#        [  7,   1,   0,   0,   0]])

# %% [markdown]
# #### Plot confusion matrix with absolute, non-normalized values

# %%
plot_confusion_matrix(
    gs, X_test, y_test,
    values_format=",",
    cmap="viridis"
)

# %% [markdown]
# #### Plot confusion matrix with normalized values

# %%
plot_confusion_matrix(
    gs, X_test, y_test,
    normalize="true",
    values_format=".2f",
    cmap="cividis"
)

# %% [markdown]
# #### Print classification report for the predictions on the _test_ set

# %%
target_names = ["Slight Damage", "Intermediate Damage", "Heavy Damage", "Partial Collapse", "Total Collapse"]
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                      precision    recall  f1-score   support
#
#       Slight Damage       0.65      0.92      0.76       130
# Intermediate Damage       0.26      0.10      0.15        49
#        Heavy Damage       0.20      0.05      0.08        19
#    Partial Collapse       0.00      0.00      0.00         5
#      Total Collapse       0.00      0.00      0.00         8
#
#            accuracy                           0.60       211
#           macro avg       0.22      0.22      0.20       211
#        weighted avg       0.48      0.60      0.51       211
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### Print balanced accuracy score for the predictions on the _test_ set

# %%
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.21554986367016443

# %% [markdown]
# ## 10: Try binary classification

# %% [markdown]
# ### Compress the damage grades into 0 and 1

# %%
# Assign buildings with no DPM value to a value of DPM=0
inputs_gdf["DAMAGE_GRADE_BINARY"] = inputs_gdf.DAMAGE_GRADE.apply(lambda x: 0 if x<=2 else 1)

# %% [markdown]
# ### Extract the training features and training labels

# %%
train_values = inputs_gdf[["CONSTR_TYPE", "AGE", "NUM_FLOORS", "SOIL_PERIOD", "MMI", "DPM_MAX"]]
train_labels = inputs_gdf[["DAMAGE_GRADE_BINARY"]]

# %%
train_values.dtypes
# Out:
# CONSTR_TYPE      int64
# AGE            float64
# NUM_FLOORS       int64
# SOIL_PERIOD    float64
# MMI            float64
# DPM_MAX        float64
# dtype: object

# %%
train_labels.dtypes
# Out:
# DAMAGE_GRADE_BINARY    int64
# dtype: object

# %% [markdown]
# ### Explore the training data

# %%
ax = (train_labels.DAMAGE_GRADE_BINARY
      .value_counts()
      .sort_index()
      .plot.bar(
          title="Number of Buildings in Each Damage Grade",
          color=["Green", "Orange"],
      ))
for p in ax.patches:
    ax.annotate(
        p.get_height(), (p.get_x()+p.get_width()/2., p.get_height()), 
        ha='center', va='center', 
        xytext=(0, 10), textcoords='offset points')

# %% [markdown]
# ### Select subset of features to use for training

# %%
selected_features = ["CONSTR_TYPE", "AGE", "NUM_FLOORS", "SOIL_PERIOD", "MMI", "DPM_MAX"]
train_values_subset = train_values[selected_features]

# %% [markdown]
# ### Explore the relationships between the numeric features and labels

# %%
sns.set_theme(style="ticks")
train_values_subset_plot = train_values_subset.replace(0, np.nan)
sns.pairplot(
    train_values_subset_plot.join(train_labels),
    hue="DAMAGE_GRADE_BINARY",
    hue_order=[1, 0],
    palette={0:"Green", 1:"Orange"},
    markers=["1", "2"],
    kind="scatter",
    diag_kind="hist",
    corner=True,
    plot_kws={'alpha':0.6, 'linewidth':1},
    diag_kws={'fill':True},
    grid_kws={'diag_sharey':False},
)
# Out:
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# /Users/anirudh/GEM/Code/venvs/horus/lib/python3.9/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('1').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)

# %% [markdown]
# ### Split dataset into training and test subsets
#
# When performing a (supervised) machine learning experiment, it is common to hold out part of the available data as a test set `X_test, y_test`. The best parameters can be determined by grid search techniques.

# %%
X_train, X_test, y_train, y_test = train_test_split(train_values_subset, train_labels, train_size=0.70, test_size=0.30, random_state=40)

# %% [markdown]
# ### Use a Extra Trees Classifier with class weights

# %%
pipe = make_pipeline(
    StandardScaler(),
    ExtraTreesClassifier(
        random_state=42,
        max_depth=None,
        min_samples_split=2,
        max_features="sqrt",
        class_weight="balanced"
    )
)
pipe
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('extratreesclassifier',
#                  ExtraTreesClassifier(class_weight='balanced',
#                                       max_features='sqrt', random_state=42))])

# %%
param_grid = {'extratreesclassifier__n_estimators': [50, 100],
              'extratreesclassifier__min_samples_leaf': [1, 5]}
gs_binary = GridSearchCV(pipe, param_grid, cv=5)
gs_binary.fit(X_train, y_train.values.ravel())
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('extratreesclassifier',
#                                         ExtraTreesClassifier(class_weight='balanced',
#                                                              max_features='sqrt',
#                                                              random_state=42))]),
#              param_grid={'extratreesclassifier__min_samples_leaf': [1, 5],
#                          'extratreesclassifier__n_estimators': [50, 100]})

# %% [markdown]
# ### Evaluate the model prediction performance on the _training set_

# %%
in_sample_preds = gs_binary.predict(train_values_subset)

# %% [markdown]
# #### Plot confusion matrix with absolute, non-normalized values

# %%
plot_confusion_matrix(
    gs_binary, train_values_subset, train_labels,
    values_format=",",
    cmap="viridis"
)

# %% [markdown]
# #### Plot confusion matrix with normalized values

# %%
plot_confusion_matrix(
    gs_binary, train_values_subset, train_labels,
    normalize="true",
    values_format=".2f",
    cmap="cividis"
)

# %% [markdown]
# ### Use the trained model to make predictions on the test set

# %%
y_pred = gs_binary.predict(X_test)

# %% [markdown]
# #### Display the confusion matrix for the predictions on the test set

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[174,   5],
#        [ 30,   2]])

# %% [markdown]
# #### Plot confusion matrix with absolute, non-normalized values

# %%
plot_confusion_matrix(
    gs_binary, X_test, y_test,
    values_format=",",
    cmap="viridis"
)

# %% [markdown]
# #### Plot confusion matrix with normalized values

# %%
plot_confusion_matrix(
    gs_binary, X_test, y_test,
    normalize="true",
    values_format=".2f",
    cmap="cividis"
)

# %% [markdown]
# #### Print classification report for the predictions on the _test_ set

# %%
target_names = ["No Damage", "Damage"]
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#    No Damage       0.85      0.97      0.91       179
#       Damage       0.29      0.06      0.10        32
#
#     accuracy                           0.83       211
#    macro avg       0.57      0.52      0.51       211
# weighted avg       0.77      0.83      0.79       211

# %% [markdown]
# #### Print balanced accuracy score for the predictions on the _test_ set

# %%
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5172835195530726

# %%
print(f"Analysis completed in {time() - starttime:.0f}s")
# Out:
# Analysis completed in 222s
